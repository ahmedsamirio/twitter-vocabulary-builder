# %% [markdown]
# This notebook contains tests for various functions in this project.

# %%
# testing collect follower 
from twitter_api import *

twitter_api = oauth_login()
user = collect_user(twitter_api, 'msha3bo')
followers = collect_followers(twitter_api, user, 200)
print(user['screen_name'], len(followers))

count = 0
for follower in followers:
    print(follower['screen_name'], len(collect_followers(twitter_api, user, 200)))
    count += 1
    if count > 5:
        break
# Out:
# MSha3bo 200
# mohamed87503112 200
# SarikaK61503956 200
# michael53128232 200
# 60Fe26 200
# MaiAmmar 200
# _3b3ziz_ 200

# %%
x = [1]
y = [2]

if x and y:
    print('yes')
# Out:
# yes

# %%
# testing collect follower 
from twitter_api import *

twitter_api = oauth_login()
user = collect_user(twitter_api, 'msha3bo')
# followers = collect_followers(twitter_api, user, 200)
# friends = collect_friends(twitter_api, user, 200)

# %%
tweets = collect_tweets(twitter_api, user, 200)
# Out:
# Fetched 119 tweets for MSha3bo
# Done fetching tweets for MSha3bo

# %%
for tweet in tweets:
    print(tweet['text'])
# Out:
# تنك https://t.co/LNUMIo8d9G
# @AymanGelberto هو فيه مدرب اجنبى جه درب مصر ب ٥٠ الف دولار؟
# @tpf_Amelie @_3b3ziz_ @joinClubhouse شوف ايفون 5 عندكو فى البيت
# @_3b3ziz_ @joinClubhouse @tpf_Amelie والله لسه بقول لرجبولى زيزو لازم يشاركنا 😂😂😂
# اللى مش معاه ايفون قدامه بكرة ينزل يشترى
# I'm discussing “محلات الفرايد تشيكن ما بين الحقيقة والسراب” with Ahmed Ragab. Today, Mar 28 at 6:00 PM GMT 2 on… https://t.co/DAAiJ0CCk1
# @Mahmoud_1ashraf @Ahmedkolkeila الصحة خلاص
# https://t.co/ufdUNUfQvu https://t.co/93GBuTVdbG
# عذر اقبح من ذنب https://t.co/1N4WvxnEfe
# اللى صورها معرفش يحط الكاميرا بين السلك؟ https://t.co/NhEsbTotOd
# اه والله https://t.co/xNKohsAQeo
# هو وليد سليمان فين؟
# هو مين بينهى الموجات وبيبدا موجة جديدة؟ https://t.co/I1KenJJPBh
# @shabanelshamy1 😂😂
# https://t.co/L78kvAjkXt
# هيعينوه مستشار فنى بعد الضهر https://t.co/wyAFT7CvJ8
# 😂😂 https://t.co/u45mOHwqwN
# ستات عواجيز بياكلوا كيك، ياحرام https://t.co/9kptP6EFYP
# ...

# %%
for follower in followers:
    if not follower['verified']:
        print(follower['screen_name'])
# Out:
# Dalia_Raafat7
# Menna01m
# yagamiikira
# BitOutrageous
# unculturedslut0
# incognitobooo
# zeftaaa_
# NOURhan_H_M
# SeseliaAdam
# el_folany
# MassCamShooterr
# ahmed12aq
# Rania19935
# clevesimiyu
# ZayMACZ
# allbouttime
# Acelam824
# Ahmad3b7akim
# bobelbanna2
# barelygoodha
# robertfarid1
# Mlracler
# Saroaa7
# mohamedalcafory
# AhmadRefaay999
# chaoticbutwtv
# Noor7XO
# randomia_ya
# m_bassam94
# nancyyyha
# So_0Mk
# 911diary991
# Lobna_qad
# a_6399
# AtW1lI36ftkimCn
# mtantawy
# salma45885938
# CarolineKarmy
# MagnumOops
# BigDeadEnergyy
# Michaelehaab
# ymgrifff
# uuuyyy___
# omarsalem___
# marmoraiaa
# Mag_n0lia
# Jl28HqTUefeFRvV
# Musiclyrics99
# yourfavretard
# bruteforceme
# Omnia58731271
# cantitbeorcanit
# Meho20753540
# Dr_3laayassine3
# MariemMaged
# Hossamnegmeldin
# __saratonin__
# bahrz88
# mrs_crap
# TEH73
# a7medelged
# Magrado_
# yarstan_
# BlueMouni
# Israasamir20
# Whenuwalkaway__
# bbc_nba1
# basel_3adel
# mahmoud79589067
# CRed1__
# waleeeed22338
# Wadoudagain
# ...
